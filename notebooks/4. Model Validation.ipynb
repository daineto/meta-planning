# %%
from meta_planning.parsers import parse_trajectory, parse_model
from meta_planning import ValidationTask

# %%
M = parse_model('../src/meta_planning/dataset/nondet-blocks-A/reference')

# %%
t1 = parse_trajectory('../src/meta_planning/dataset/nondet-blocks-B/trajectory-00', M)
trajectories = [parse_trajectory('../src/meta_planning/dataset/nondet-blocks-A/trajectory-%s' % str(i).zfill(2), M) for i in range(10)]

# %%
O = [t.observe(1, action_observability = 0, keep_every_state=True) for t in trajectories]

# %%
print(O[0].number_of_states)
# Out:
# 26

# %%
task = ValidationTask(M,O[:1], allow_insertions=True, allow_deletions=True)

# %%
print(task.compiled_model)
# Out:
# (define (domain blocks)
# (:requirements :strips)
# (:predicates
# 	(on ?x - object ?y - object)
# 	(ontable ?x - object)
# 	(clear ?x - object)
# 	(handempty )
# 	(holding ?x - object)
# 	(pre_pick-up_ontable_var1 )
# 	(eff_pick-up_ontable_var1 )
# 	(pre_pick-up_clear_var1 )
# 	(eff_pick-up_clear_var1 )
# 	(pre_pick-up_handempty )
# 	(eff_pick-up_handempty )
# 	(pre_pick-up_holding_var1 )
# 	(eff_pick-up_holding_var1 )
# 	(pre_put-down_ontable_var1 )
# 	(eff_put-down_ontable_var1 )
# 	(pre_put-down_clear_var1 )
# 	(eff_put-down_clear_var1 )
# 	(pre_put-down_handempty )
# 	(eff_put-down_handempty )
# 	(pre_put-down_holding_var1 )
# 	(eff_put-down_holding_var1 )
# 	(pre_stack-ok_on_var1_var1 )
# 	(eff_stack-ok_on_var1_var1 )
# 	(pre_stack-ok_on_var1_var2 )
# 	(eff_stack-ok_on_var1_var2 )
# 	(pre_stack-ok_on_var2_var1 )
# 	(eff_stack-ok_on_var2_var1 )
# 	(pre_stack-ok_on_var2_var2 )
# 	(eff_stack-ok_on_var2_var2 )
# 	(pre_stack-ok_ontable_var1 )
# 	(eff_stack-ok_ontable_var1 )
# ...

# %%
solution = task.validate(parallel=False)
# Out:
# /home/dieaigar/PhD/meta-planning/src/meta_planning/util/planners/madagascar/M compiled_domain compiled_problem -S 1 -Q -o solution_plan -F 51 -P 0 > planner_out

# %%
solution

# %%
print(solution.solution_plan)
# Out:
# 0 : (validate_0 )
# 1 : (unstack-ok c d)
# 2 : (validate_1 )
# 3 : (stack c a)
# 4 : (validate_2 )
# 5 : (put-down c)
# 6 : (validate_3 )
# 7 : (unstack-ok d b)
# 8 : (validate_4 )
# 9 : (put-down d)
# 10 : (validate_5 )
# 11 : (unstack-ok b e)
# 12 : (validate_6 )
# 13 : (stack-ok b e)
# 14 : (validate_7 )
# 15 : (unstack-ok b e)
# 16 : (validate_8 )
# 17 : (stack-ok b e)
# 18 : (validate_9 )
# 19 : (unstack-ok b e)
# 20 : (validate_10 )
# 21 : (stack b d)
# 22 : (validate_11 )
# 23 : (put-down b)
# 24 : (validate_12 )
# 25 : (unstack-ok e f)
# 26 : (validate_13 )
# 27 : (stack e a)
# 28 : (validate_14 )
# 29 : (put-down e)
# 30 : (validate_15 )
# 31 : (pick-up b)
# 32 : (validate_16 )
# 33 : (stack b c)
# 34 : (validate_17 )
# 35 : (put-down b)
# 36 : (validate_18 )
# 37 : (pick-up b)
# 38 : (validate_19 )
# 39 : (put-down b)
# 40 : (validate_20 )
# 41 : (pick-up b)
# 42 : (validate_21 )
# 43 : (put-down b)
# 44 : (validate_22 )
# 45 : (pick-up b)
# 46 : (validate_23 )
# ...

# %%
explanation = solution.explanations[0]
print(explanation.plan)
# Out:
# 0 : (unstack-ok c d)
# 1 : (stack c a)
# 2 : (put-down c)
# 3 : (unstack-ok d b)
# 4 : (put-down d)
# 5 : (unstack-ok b e)
# 6 : (stack-ok b e)
# 7 : (unstack-ok b e)
# 8 : (stack-ok b e)
# 9 : (unstack-ok b e)
# 10 : (stack b d)
# 11 : (put-down b)
# 12 : (unstack-ok e f)
# 13 : (stack e a)
# 14 : (put-down e)
# 15 : (pick-up b)
# 16 : (stack b c)
# 17 : (put-down b)
# 18 : (pick-up b)
# 19 : (put-down b)
# 20 : (pick-up b)
# 21 : (put-down b)
# 22 : (pick-up b)
# 23 : (put-down b)
# 24 : (pick-up b)
