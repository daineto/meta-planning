# %%
from meta_planning import dataset
from meta_planning import LearningTask
from meta_planning.evaluation import SynEvaluator

# %% [markdown]
# # Model Learning
#
# A model learning task is defined as $\Lambda = <m,\mathcal{O}>$, where
#
# * $m$ is the initial empty domain model
# * $\mathcal{O}$ is a set of observations
#
# A solution to $\Lambda$ consists of:
# * a model $m'$ consistent with $m$ and $\mathcal{O}$
# * a set of of explanations $\mathcal{E} = \{<t,o> | o \in \mathcal{O}\}$ where $t$ is a trajectory generated by $m'$ and consistent with $o$

# %% [markdown]
# ### Pick a domain

# %%
dataset.list_learning_domains()
# Out:
# Learning domains:
# 	 blocks
# 	 driverlog
# 	 ferry
# 	 floortile
# 	 grid
# 	 gripper
# 	 hanoi
# 	 miconic
# 	 npuzzle
# 	 parking
# 	 rovers
# 	 satellite
# 	 transport
# 	 visitall
# 	 zenotravel

# %%
domain = "blocks"

# %% [markdown]
# ### Define the initial model

# %%
m_ref = dataset.load_model(domain)

m = m_ref.observe(precondition_observability=0, effect_observability=0)

print(m)
# Out:
# (define (domain blocks)
# (:requirements :strips)
# (:types object)
# (:predicates
# 	(on ?o1 - object ?o2 - object)
# 	(ontable ?o1 - object)
# 	(clear ?o1 - object)
# 	(handempty )
# 	(holding ?o1 - object)
# )
#
# (:action pick-up
# 	:parameters (?o1 - object)
# 	:precondition (and )
# 	:effect (and
# 	)
# )
#
# (:action put-down
# 	:parameters (?o1 - object)
# 	:precondition (and )
# 	:effect (and
# 	)
# )
#
# (:action stack
# 	:parameters (?o1 - object ?o2 - object)
# 	:precondition (and )
# 	:effect (and
# 	)
# )
#
# (:action unstack
# 	:parameters (?o1 - object ?o2 - object)
# 	:precondition (and )
# 	:effect (and
# 	)
# ))

# %% [markdown]
# ### Define the observations
#
# An observation is a partially observed trajectory $\tau = <s_0, a_1, s_1, \ldots, a_n, s_n >$.
#
# **Setting 1 - Bounded solution:** The length of the observed trajectory is known when:
# * every action is observed, or
# * every state is observed (even partially).
#
# **Setting 2 - Unbounded solution:** The observation is not indicative of the length of the trajectory when:
# * there are missing actions, and
# * there are missing states.

# %%
num_observations = 2 #1-10
T = dataset.load_trajectories(domain, select=range(num_observations))

O = [t.observe(0.2, action_observability=0, goal_observability=1, keep_every_state=False) for t in T]

print(O[0])
# Out:
# (observation
#
# (:objects e - object b - object f - object d - object c - object g - object a - object)
#
# (:state (clear a) (not (clear b)) (clear c) (not (clear d)) (not (clear e)) (not (clear f)) (not (clear g)) (handempty ) (not (holding a)) (not (holding b)) (not (holding c)) (not (holding d)) (not (holding e)) (not (holding f)) (not (holding g)) (not (on a a)) (not (on a b)) (not (on a c)) (not (on a d)) (not (on a e)) (not (on a f)) (on a g) (not (on b a)) (not (on b b)) (not (on b c)) (not (on b d)) (on b e) (not (on b f)) (not (on b g)) (not (on c a)) (not (on c b)) (not (on c c)) (on c d) (not (on c e)) (not (on c f)) (not (on c g)) (not (on d a)) (on d b) (not (on d c)) (not (on d d)) (not (on d e)) (not (on d f)) (not (on d g)) (not (on e a)) (not (on e b)) (not (on e c)) (not (on e d)) (not (on e e)) (on e f) (not (on e g)) (not (on f a)) (not (on f b)) (not (on f c)) (not (on f d)) (not (on f e)) (not (on f f)) (not (on f g)) (not (on g a)) (not (on g b)) (not (on g c)) (not (on g d)) (not (on g e)) (not (on g f)) (not (on g g)) (not (ontable a)) (not (ontable b)) (not (ontable c)) (not (ontable d)) (not (ontable e)) (ontable f) (ontable g))
#
# (:state (clear a) (not (clear c)) (not (clear e)) (not (holding a)) (not (holding e)) (not (holding g)) (not (on a b)) (not (on a f)) (on a g) (not (on b b)) (not (on e d)) (on e f) (not (on f c)) (not (on f f)) (not (on g c)) (not (on g d)) (not (on g f)))
#
# (:state (clear c) (not (clear g)) (handempty ) (not (holding a)) (not (holding g)) (not (on a a)) (not (on a c)) (not (on a e)) (on a g) (not (on d c)) (not (on d e)) (not (on e a)) (on e f) (not (on f e)) (not (on f f)) (not (ontable a)) (not (ontable e)))
#
# (:state (not (holding a)) (not (holding b)) (not (holding c)) (not (holding f)) (not (on a a)) (not (on c e)) (not (on d e)) (not (on d f)) (not (on f b)) (not (on f d)) (not (on g a)) (not (on g e)) (ontable c) (not (ontable e)))
#
# (:state (not (holding c)) (not (holding d)) (not (on a a)) (not (on a c)) (not (on c d)) (not (on c f)) (not (on d d)) (not (on d e)) (not (on e g)) (not (on f d)) (not (on f f)) (not (on g c)) (not (ontable b)) (not (ontable e)) (ontable g))
#
# (:state (not (clear a)) (clear d) (holding b) (not (holding c)) (not (holding g)) (not (on a b)) (not (on b d)) (not (on b e)) (not (on c a)) (not (on c e)) (not (on d c)) (not (on e a)) (not (on e d)) (not (on e e)) (not (on f a)) (not (on f c)) (not (on f d)) (not (on f e)) (not (on g b)) (not (on g c)) (not (on g e)) (ontable g))
#
# (:state (clear e) (not (clear f)) (not (holding a)) (not (on b d)) (not (on c a)) (not (on c e)) (on d a) (not (on d c)) (not (on e c)) (not (on e d)) (not (on f d)) (not (on g b)) (not (on g c)) (not (on g e)) (ontable c))
#
# (:state (clear e) (not (clear f)) (not (clear g)) (not (holding g)) (not (on a a)) (not (on a e)) (on a g) (not (on b b)) (not (on b e)) (not (on b f)) (not (on c e)) (not (on d c)) (not (on d d)) (not (on e e)) (not (on f b)) (not (on f d)) (not (on g e)) (not (on g f)) (ontable b) (not (ontable d)) (ontable f))
#
# (:state (clear e) (not (holding a)) (not (holding b)) (not (holding c)) (not (holding e)) (not (on a e)) (not (on b f)) (not (on e d)) (not (on f c)) (not (on f d)) (not (on f f)))
#
# (:state (not (holding a)) (not (holding c)) (not (holding e)) (not (on a a)) (not (on a e)) (not (on b a)) (not (on b b)) (not (on d b)) (not (on d c)) (not (on f a)) (not (on f b)) (not (on g c)) (not (on g g)) (ontable b) (not (ontable e)))
#
# (:state (clear a) (clear b) (clear c) (clear d) (clear e) (not (clear f)) (not (clear g)) (handempty ) (not (holding a)) (not (holding b)) (not (holding c)) (not (holding d)) (not (holding e)) (not (holding f)) (not (holding g)) (not (on a a)) (not (on a b)) (not (on a c)) (not (on a d)) (not (on a e)) (not (on a f)) (on a g) (not (on b a)) (not (on b b)) (not (on b c)) (not (on b d)) (not (on b e)) (not (on b f)) (not (on b g)) (not (on c a)) (not (on c b)) (not (on c c)) (not (on c d)) (not (on c e)) (not (on c f)) (not (on c g)) (not (on d a)) (not (on d b)) (not (on d c)) (not (on d d)) (not (on d e)) (not (on d f)) (not (on d g)) (not (on e a)) (not (on e b)) (not (on e c)) (not (on e d)) (not (on e e)) (on e f) (not (on e g)) (not (on f a)) (not (on f b)) (not (on f c)) (not (on f d)) (not (on f e)) (not (on f f)) (not (on f g)) (not (on g a)) (not (on g b)) (not (on g c)) (not (on g d)) (not (on g e)) (not (on g f)) (not (on g g)) (not (ontable a)) (ontable b) (ontable c) (ontable d) (not (ontable e)) (ontable f) (ontable g)))

# %% [markdown]
# ### Solve the task

# %%
task = LearningTask(m,O)

solution = task.learn()
# Out:
# ulimit -t 3000; /home/dieaigar/PhD/meta-planning/src/meta_planning/util/planners/madagascar/M compiled_domain compiled_problem -S 1 -Q -o solution_plan -F 41 > planner_out

# %%
print(solution.learned_model)
# Out:
# (define (domain blocks)
# (:requirements :strips)
# (:types object)
# (:predicates
# 	(on ?o1 - object ?o2 - object)
# 	(ontable ?o1 - object)
# 	(clear ?o1 - object)
# 	(handempty )
# 	(holding ?o1 - object)
# )
#
# (:action pick-up
# 	:parameters (?o1 - object)
# 	:precondition (and (holding ?o1))
# 	:effect (and
# 		(not (holding ?o1))
# 		(clear ?o1)
# 		(ontable ?o1)
# 		(handempty )
# 		0
# 	)
# )
#
# (:action put-down
# 	:parameters (?o1 - object)
# 	:precondition (and (clear ?o1))
# 	:effect (and
# 		(holding ?o1)
# 		(not (clear ?o1))
# 		(ontable ?o1)
# 		0
# 	)
# )
#
# (:action stack
# 	:parameters (?o1 - object ?o2 - object)
# 	:precondition (and (on ?o1 ?o2) (handempty ))
# 	:effect (and
# 		(holding ?o1)
# 		(clear ?o2)
# 		(not (on ?o1 ?o2))
# 		(clear ?o1)
# 		0
# 	)
# )
#
# (:action unstack
# 	:parameters (?o1 - object ?o2 - object)
# 	:precondition (and (holding ?o1) (ontable ?o1))
# 	:effect (and
# 		(not (holding ?o1))
# 		(on ?o2 ?o1)
# 		(not (ontable ?o1))
# 		0
# 	)
# ))

# %%
print(solution.solution_plan)
# Out:
# 0 : (insert_eff_pick-up_clear_var1 )
# 1 : (insert_eff_pick-up_handempty )
# 2 : (insert_eff_pick-up_holding_var1 )
# 3 : (insert_eff_pick-up_ontable_var1 )
# 4 : (insert_eff_put-down_clear_var1 )
# 5 : (insert_eff_put-down_holding_var1 )
# 6 : (insert_eff_put-down_ontable_var1 )
# 7 : (insert_eff_stack_clear_var1 )
# 8 : (insert_eff_stack_clear_var2 )
# 9 : (insert_eff_stack_holding_var1 )
# 10 : (insert_eff_stack_on_var1_var2 )
# 11 : (insert_eff_unstack_holding_var1 )
# 12 : (insert_eff_unstack_on_var2_var1 )
# 13 : (insert_eff_unstack_ontable_var1 )
# 14 : (insert_pre_pick-up_holding_var1 )
# 15 : (insert_pre_put-down_clear_var1 )
# 16 : (insert_pre_stack_handempty )
# 17 : (insert_pre_stack_on_var1_var2 )
# 18 : (insert_pre_unstack_holding_var1 )
# 19 : (insert_pre_unstack_ontable_var1 )
# 20 : (validate_0 )
# 21 : (put-down c)
# 22 : (validate_1 )
# 23 : (stack c d)
# 24 : (validate_2 )
# 25 : (pick-up c)
# 26 : (validate_3 )
# 27 : (stack b e)
# 28 : (validate_4 )
# 29 : (put-down a)
# 30 : (validate_5 )
# 31 : (unstack a d)
# 32 : (validate_6 )
# 33 : (pick-up b)
# 34 : (validate_7 )
# 35 : (stack d b)
# 36 : (validate_8 )
# 37 : (stack d a)
# 38 : (validate_9 )
# 39 : (pick-up d)
# 40 : (validate_10 )
# 41 : (stack e f)
# 42 : (put-down e)
# 43 : (validate_11 )
# 44 : (pick-up e)
# 45 : (validate_12 )
# 46 : (stack a g)
# 47 : (validate_13 )
# 48 : (pick-up a)
# 49 : (validate_14 )
# 50 : (put-down a)
# 51 : (validate_15 )
# 52 : (pick-up a)
# 53 : (validate_16 )
# 54 : (put-down b)
# 55 : (validate_17 )
# 56 : (unstack b b)
# 57 : (validate_18 )
# 58 : (stack b b)
# 59 : (validate_19 )
# 60 : (pick-up b)
# 61 : (validate_20 )

# %% [markdown]
# ### Evaluate the learned model

# %% [markdown]
# ### Evaluate the learned model
#
# The evaluation metrics are:
#
# $Precision=\frac{tp}{tp+fp}=\frac{size(\mathcal{M})- \left|DEL(\mathcal{M},GTM)\right|}{size(\mathcal{M})}$
#
# $Recall= \frac{tp}{tp+fn}=\frac{size(\mathcal{M})- \left|DEL(\mathcal{M},GTM)\right|}{size(\mathcal{M}) - \left|DEL(\mathcal{M},GTM)\right| + \left|INS(\mathcal{M},GTM)\right|}$

# %%
evaluator = SynEvaluator(solution.learned_model, m_ref)

evaluator.evaluate()
# Out:
# (:action put-down
# 	:parameters (?o1 - object)
# 	:precondition (and
# 		(clear ?o1)
# 		(handempty )
# 		(ontable ?o1)
# 	)
# 	:effects (and
# 		(not (clear ?o1))
# 		(holding ?o1)
# 		(ontable ?o1)
# 		(not (handempty ))
# 		(not (ontable ?o1))
# 	)
# )
#
# (:action pick-up
# 	:parameters (?o1 - object)
# 	:precondition (and
# 		(holding ?o1)
# 	)
# 	:effects (and
# 		(handempty )
# 		(clear ?o1)
# 		(not (holding ?o1))
# 		(ontable ?o1)
# 	)
# )
#
# (:action unstack
# 	:parameters (?o1 - object ?o2 - object)
# 	:precondition (and
# 		(holding ?o1)
# 		(ontable ?o1)
# 		(clear ?o2)
# 	)
# 	:effects (and
# 		(not (holding ?o1))
# 		(not (ontable ?o1))
# 		(on ?o2 ?o1)
# 		(handempty )
# 		(clear ?o1)
# 		(on ?o1 ?o2)
# 		(not (clear ?o2))
# 	)
# )
#
# (:action stack
# 	:parameters (?o1 - object ?o2 - object)
# 	:precondition (and
# 		(handempty )
# 		(on ?o1 ?o2)
# 		(clear ?o1)
# 	)
# 	:effects (and
# 		(holding ?o1)
# 		(not (on ?o1 ?o2))
# 		(clear ?o2)
# 		(clear ?o1)
# 		(not (handempty ))
# 		(not (clear ?o1))
# 	)
# )
#
# F1 score: 0.6382978723404256
# PRE precision: 0.8333333333333334, recall 0.5555555555555556
# ADD precision: 0.6666666666666666, recall 0.6666666666666666
# DEL precision: 0.8, recall 0.4444444444444444
# AVG precision: 0.75, recall 0.5555555555555556
# Matchings:
# 	Matching(pick-up, put-down, (0,))
# 	Matching(put-down, pick-up, (0,))
# 	Matching(stack, unstack, (0, 1))
# 	Matching(unstack, stack, (0, 1))
